# %%
# !java -Xmx6g -jar science-parse-cli-assembly-2.0.3.jar ./papers -o ./json
# Out:
# 20:37:02.794 [main] DEBUG com.amazonaws.AmazonWebServiceClient - Internal logging successfully configured to commons logger: true
# 20:37:02.847 [main] DEBUG com.amazonaws.metrics.AwsSdkMetrics - Admin mbean registered under com.amazonaws.management:type=AwsSdkMetrics
# 20:37:02.881 [main] DEBUG c.a.internal.config.InternalConfig - Configuration override awssdk_config_override.json not found.
# 20:37:14.438 [main] INFO  org.allenai.datastore.Datastore - Downloading org.allenai.scienceparse/productionModel-v9.dat from the public datastore. 2.00 MB read.
# 20:37:15.459 [main] INFO  org.allenai.datastore.Datastore - Downloading org.allenai.scienceparse/productionModel-v9.dat from the public datastore. 14.0 MB read.
# 20:37:16.618 [main] INFO  org.allenai.datastore.Datastore - Downloading org.allenai.scienceparse/productionModel-v9.dat from the public datastore. 27.0 MB read.
# ...
