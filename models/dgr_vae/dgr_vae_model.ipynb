# %%
# %load_ext autoreload
# %autoreload 2

# %%
from dgr_bert_model import *
from dgr_vae_model import *
from dgr_utils import *

# %%
# Use GPU
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
print("Available device: {}".format(device))
if use_cuda:
    print(torch.cuda.get_device_name(0))
# Out:
# Available device: cuda:0
# NVIDIA GeForce GTX 1070

# %%
"""
Builds and trains a VAE model on the extracted features from the FeatureExtractor

VAE model can be used to reconstruct or generate new features
"""

# %%
bert_lstm = torch.load('data/model_bert_854.pth')

feature_extractor = torch.load('data/feature_extractor.pth')
feature_classifier = torch.load('data/feature_classifier.pth')

# %%
train_features_sample = torch.load('data/train_features_sample.pt')
train_features_label = torch.load('data/train_features_label.pt')

val_features_sample = torch.load('data/val_features_sample.pt')
val_features_label = torch.load('data/val_features_label.pt')

# %%
batch_size = 32

train_features_dataset = TensorDataset(train_features_sample, train_features_label)
train_features_sampler = RandomSampler(train_features_dataset)
train_features_dataloader = DataLoader(train_features_dataset, 
                                  sampler=train_features_sampler, 
                                  batch_size=batch_size)


val_features_dataset = TensorDataset(val_features_sample, val_features_label)
val_features_sampler = RandomSampler(val_features_dataset)
val_features_dataloader = DataLoader(val_features_dataset, 
                                  sampler=val_features_sampler, 
                                  batch_size=batch_size)

# %%
input_dim = 1024
latent_dim = 128

vae = VAE(input_dim, latent_dim).to(device)
print(vae)

optimizer = torch.optim.Adam(vae.parameters(), lr=0.0001)
# Out:
# VAE(
#   (encoder): Sequential(
#     (0): Linear(in_features=1024, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=256, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=128, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=1024, bias=True)
#     (5): Tanh()
#   )
# )

# %%
num_epoch = 100

best_loss = float('inf')

for epoch in range(1, num_epoch + 1):
    vae.train()
    epoch_loss = train_epoch_vae(vae, train_features_dataloader, optimizer, device)
    
    vae.eval()
    val_loss = eval_vae(vae, val_features_dataloader, device)
    
    print("Epoch: {} train_oss: {:.5f} val_loss: {:.5f}".format(epoch, epoch_loss, val_loss))
    
    if val_loss < best_loss:
        model_checkpoint_path = 'data/vae.pth'
        torch.save(vae, model_checkpoint_path)
        print("saving model checkpoint to {}".format(model_checkpoint_path))
        
        best_loss = val_loss
# Out:
# Epoch: 1 train_oss: 451.47124 val_loss: 455.90908
# saving model checkpoint to data/vae.pth
# Epoch: 2 train_oss: 302.78167 val_loss: 288.45377
# saving model checkpoint to data/vae.pth
# Epoch: 3 train_oss: 258.52272 val_loss: 278.08301
# saving model checkpoint to data/vae.pth
# Epoch: 4 train_oss: 256.02034 val_loss: 278.65415
# Epoch: 5 train_oss: 246.41565 val_loss: 235.90972
# saving model checkpoint to data/vae.pth
# Epoch: 6 train_oss: 199.55964 val_loss: 212.65284
# saving model checkpoint to data/vae.pth
# Epoch: 7 train_oss: 191.90834 val_loss: 207.18986
# saving model checkpoint to data/vae.pth
# Epoch: 8 train_oss: 189.27628 val_loss: 202.58018
# saving model checkpoint to data/vae.pth
# Epoch: 9 train_oss: 187.86692 val_loss: 201.20388
# saving model checkpoint to data/vae.pth
# Epoch: 10 train_oss: 190.23083 val_loss: 196.86234
# saving model checkpoint to data/vae.pth
# Epoch: 11 train_oss: 186.32210 val_loss: 198.95958
# Epoch: 12 train_oss: 184.18966 val_loss: 199.47740
# Epoch: 13 train_oss: 183.22485 val_loss: 190.90834
# saving model checkpoint to data/vae.pth
# Epoch: 14 train_oss: 180.50927 val_loss: 196.46154
# Epoch: 15 train_oss: 181.17936 val_loss: 189.77205
# saving model checkpoint to data/vae.pth
# Epoch: 16 train_oss: 177.51967 val_loss: 189.62193
# saving model checkpoint to data/vae.pth
# Epoch: 17 train_oss: 174.36606 val_loss: 188.21195
# saving model checkpoint to data/vae.pth
# Epoch: 18 train_oss: 171.48217 val_loss: 179.54013
# saving model checkpoint to data/vae.pth
# Epoch: 19 train_oss: 168.10211 val_loss: 174.60257
# saving model checkpoint to data/vae.pth
# Epoch: 20 train_oss: 161.95683 val_loss: 164.87487
# saving model checkpoint to data/vae.pth
# Epoch: 21 train_oss: 158.00606 val_loss: 165.20273
# Epoch: 22 train_oss: 152.23201 val_loss: 165.45196
# Epoch: 23 train_oss: 149.66308 val_loss: 161.39490
# saving model checkpoint to data/vae.pth
# Epoch: 24 train_oss: 146.61979 val_loss: 153.16955
# saving model checkpoint to data/vae.pth
# Epoch: 25 train_oss: 146.67288 val_loss: 153.30995
# Epoch: 26 train_oss: 143.91573 val_loss: 153.53958
# Epoch: 27 train_oss: 142.74978 val_loss: 153.00367
# saving model checkpoint to data/vae.pth
# Epoch: 28 train_oss: 142.27738 val_loss: 148.49287
# saving model checkpoint to data/vae.pth
# Epoch: 29 train_oss: 141.37973 val_loss: 146.71635
# saving model checkpoint to data/vae.pth
# Epoch: 30 train_oss: 139.59201 val_loss: 149.35786
# Epoch: 31 train_oss: 138.12126 val_loss: 147.66138
# Epoch: 32 train_oss: 137.22664 val_loss: 145.19944
# saving model checkpoint to data/vae.pth
# Epoch: 33 train_oss: 136.52929 val_loss: 142.98711
# saving model checkpoint to data/vae.pth
# Epoch: 34 train_oss: 134.14005 val_loss: 142.08845
# saving model checkpoint to data/vae.pth
# Epoch: 35 train_oss: 133.77161 val_loss: 139.61518
# saving model checkpoint to data/vae.pth
# Epoch: 36 train_oss: 129.95809 val_loss: 137.10773
# saving model checkpoint to data/vae.pth
# Epoch: 37 train_oss: 132.23256 val_loss: 138.42142
# Epoch: 38 train_oss: 132.31281 val_loss: 135.62422
# saving model checkpoint to data/vae.pth
# Epoch: 39 train_oss: 129.95878 val_loss: 132.52648
# saving model checkpoint to data/vae.pth
# Epoch: 40 train_oss: 127.68958 val_loss: 134.43976
# Epoch: 41 train_oss: 126.25325 val_loss: 129.90016
# saving model checkpoint to data/vae.pth
# Epoch: 42 train_oss: 126.05134 val_loss: 132.16808
# Epoch: 43 train_oss: 124.54792 val_loss: 130.31656
# Epoch: 44 train_oss: 123.40472 val_loss: 131.43709
# Epoch: 45 train_oss: 122.14037 val_loss: 128.00507
# saving model checkpoint to data/vae.pth
# Epoch: 46 train_oss: 120.57886 val_loss: 125.52354
# saving model checkpoint to data/vae.pth
# Epoch: 47 train_oss: 119.10883 val_loss: 126.53579
# Epoch: 48 train_oss: 118.91603 val_loss: 128.84104
# Epoch: 49 train_oss: 119.91459 val_loss: 127.08556
# Epoch: 50 train_oss: 118.98410 val_loss: 122.12734
# saving model checkpoint to data/vae.pth
# Epoch: 51 train_oss: 117.85192 val_loss: 125.01722
# Epoch: 52 train_oss: 116.69484 val_loss: 123.63341
# Epoch: 53 train_oss: 116.18114 val_loss: 126.47496
# Epoch: 54 train_oss: 117.07752 val_loss: 122.71537
# Epoch: 55 train_oss: 116.29806 val_loss: 123.54911
# Epoch: 56 train_oss: 116.02490 val_loss: 122.55208
# Epoch: 57 train_oss: 114.79206 val_loss: 121.30556
# saving model checkpoint to data/vae.pth
# Epoch: 58 train_oss: 115.25505 val_loss: 120.75532
# saving model checkpoint to data/vae.pth
# Epoch: 59 train_oss: 114.36366 val_loss: 118.97970
# saving model checkpoint to data/vae.pth
# Epoch: 60 train_oss: 114.54472 val_loss: 118.24652
# saving model checkpoint to data/vae.pth
# Epoch: 61 train_oss: 113.89770 val_loss: 119.79364
# Epoch: 62 train_oss: 114.02404 val_loss: 122.62698
# Epoch: 63 train_oss: 113.59655 val_loss: 118.36062
# Epoch: 64 train_oss: 113.44519 val_loss: 121.56828
# Epoch: 65 train_oss: 113.67164 val_loss: 118.50024
# Epoch: 66 train_oss: 112.65397 val_loss: 119.87891
# Epoch: 67 train_oss: 112.81807 val_loss: 119.19782
# Epoch: 68 train_oss: 113.28520 val_loss: 117.47054
# saving model checkpoint to data/vae.pth
# Epoch: 69 train_oss: 112.02504 val_loss: 119.25079
# Epoch: 70 train_oss: 111.41237 val_loss: 118.25359
# Epoch: 71 train_oss: 111.96844 val_loss: 118.10737
# Epoch: 72 train_oss: 111.68365 val_loss: 116.99997
# saving model checkpoint to data/vae.pth
# Epoch: 73 train_oss: 111.99766 val_loss: 116.74934
# saving model checkpoint to data/vae.pth
# Epoch: 74 train_oss: 111.55421 val_loss: 116.67525
# saving model checkpoint to data/vae.pth
# Epoch: 75 train_oss: 112.11945 val_loss: 117.48671
# Epoch: 76 train_oss: 110.45161 val_loss: 116.69861
# Epoch: 77 train_oss: 111.31993 val_loss: 116.02209
# saving model checkpoint to data/vae.pth
# Epoch: 78 train_oss: 110.92480 val_loss: 117.66710
# Epoch: 79 train_oss: 109.83435 val_loss: 116.03995
# Epoch: 80 train_oss: 110.16242 val_loss: 115.60259
# saving model checkpoint to data/vae.pth
# Epoch: 81 train_oss: 110.31900 val_loss: 115.28222
# saving model checkpoint to data/vae.pth
# Epoch: 82 train_oss: 110.49468 val_loss: 116.42432
# Epoch: 83 train_oss: 110.18576 val_loss: 115.62824
# Epoch: 84 train_oss: 109.71586 val_loss: 116.57729
# Epoch: 85 train_oss: 110.24209 val_loss: 114.07710
# saving model checkpoint to data/vae.pth
# Epoch: 86 train_oss: 108.90967 val_loss: 116.18535
# Epoch: 87 train_oss: 109.63744 val_loss: 115.57808
# Epoch: 88 train_oss: 109.23121 val_loss: 112.69731
# saving model checkpoint to data/vae.pth
# Epoch: 89 train_oss: 109.44014 val_loss: 112.22737
# saving model checkpoint to data/vae.pth
# Epoch: 90 train_oss: 108.47145 val_loss: 113.65090
# Epoch: 91 train_oss: 108.70032 val_loss: 114.75368
# Epoch: 92 train_oss: 110.17175 val_loss: 117.98436
# Epoch: 93 train_oss: 107.96650 val_loss: 112.81811
# Epoch: 94 train_oss: 108.85176 val_loss: 113.00065
# Epoch: 95 train_oss: 109.30797 val_loss: 112.88820
# Epoch: 96 train_oss: 107.76937 val_loss: 111.23478
# saving model checkpoint to data/vae.pth
# Epoch: 97 train_oss: 108.88934 val_loss: 112.96846
# Epoch: 98 train_oss: 108.37094 val_loss: 114.59185
# Epoch: 99 train_oss: 107.19710 val_loss: 113.52565
# Epoch: 100 train_oss: 107.42347 val_loss: 113.58662

# %%
latent_sample = torch.randn(1, latent_dim).to(device)
with torch.no_grad():
    generated_item = vae.decoder(latent_sample)
    
print(generated_item)
# Out:
# tensor([[ 0.0250,  0.0772, -0.0244,  ...,  0.2842, -0.1136,  0.0600]],
#        device='cuda:0')
